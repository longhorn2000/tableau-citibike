# %%
import os
import pandas as pd
import csv

# %%
df1 = pd.read_csv("Jan_2020_citibike.csv")

# %%
df1.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0          1553   07:13.9  33:07.7              3681           Grand St
# 1           416   16:40.5  23:36.6              3195            Sip Ave
# 2           294   20:29.8  25:24.0              3195            Sip Ave
# 3            97   21:13.8  22:51.6              3202       Newport PATH
# 4           286   29:58.0  34:44.2              3195            Sip Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.715178               -74.037683            3198
# 1               40.730897               -74.063913            3679
# 2               40.730897               -74.063913            3678
# 3               40.727224               -74.033759            3638
# 4               40.730897               -74.063913            3679
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0  Heights Elevator             40.748716             -74.040443   29462
# 1        Bergen Ave             40.722104             -74.071455   29610
# 2     Fairmount Ave             40.725726             -74.071959   26166
# 3     Washington St             40.724294             -74.035483   29492
# 4        Bergen Ave             40.722104             -74.071455   29440
#
#      usertype  birth year  gender
# 0  Subscriber        1980       1
# 1  Subscriber        1956       1
# 2  Subscriber        1977       1
# 3  Subscriber        1993       1
# 4    Customer        1990       1

# %%
df2 = pd.read_csv("Feb_2020_citibike.csv")

# %%
df2.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           226   04:50.2  08:37.0              3186      Grove St PATH
# 1           377   16:01.7  22:19.1              3186      Grove St PATH
# 2           288   17:33.9  22:22.4              3186      Grove St PATH
# 3           435   32:05.9  39:21.1              3195            Sip Ave
# 4           231   46:19.7  50:11.3              3186      Grove St PATH
#
#    start station latitude  start station longitude  end station id  \
# 0               40.719586               -74.043117            3211
# 1               40.719586               -74.043117            3269
# 2               40.719586               -74.043117            3269
# 3               40.730897               -74.063913            3280
# 4               40.719586               -74.043117            3276
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0        Newark Ave             40.721525             -74.046305   29444
# 1   Brunswick & 6th             40.726012             -74.050389   26305
# 2   Brunswick & 6th             40.726012             -74.050389   29268
# 3       Astor Place             40.719282             -74.071262   29278
# 4  Marin Light Rail             40.714584             -74.042817   29276
#
#      usertype  birth year  gender
# 0  Subscriber        1984       2
# 1  Subscriber        1989       2
# 2    Customer        1989       1
# 3    Customer        1969       0
# 4  Subscriber        1983       2

# %% [markdown]
# df3 = pd.read_csv("Mar_2020_citibike.csv")

# %%
df3 = pd.read_csv("Mar_2020_citibike.csv")

# %%
df3.head()
# Out:
#    tripduration starttime stoptime  start station id  start station name  \
# 0           841   02:13.8  16:15.5              3199        Newport Pkwy
# 1           206   16:11.4  19:37.4              3273        Manila & 1st
# 2           859   23:22.1  37:41.5              3185           City Hall
# 3           693   25:14.5  36:48.0              3185           City Hall
# 4          1473   32:30.5  57:04.4              3192  Liberty Light Rail
#
#    start station latitude  start station longitude  end station id  \
# 0               40.728745               -74.032108            3213
# 1               40.721651               -74.042884            3639
# 2               40.717733               -74.043845            3268
# 3               40.717733               -74.043845            3277
# 4               40.711242               -74.055701            3639
#
#           end station name  end station latitude  end station longitude  \
# 0           Van Vorst Park             40.718489             -74.047727
# 1               Harborside             40.719252             -74.034234
# 2           Lafayette Park             40.713464             -74.062859
# 3  Communipaw & Berry Lane             40.714358             -74.066611
# 4               Harborside             40.719252             -74.034234
#
#    bikeid    usertype  birth year  gender
# 0   42217  Subscriber        1980       1
# 1   42160  Subscriber        1990       1
# 2   42204    Customer        1991       1
# 3   42165  Subscriber        1987       1
# 4   26156    Customer        1969       0

# %%
frames = [df1, df2, df3,]
df = pd.concat(frames).drop_duplicates()

# %%
df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0          1553   07:13.9  33:07.7              3681           Grand St
# 1           416   16:40.5  23:36.6              3195            Sip Ave
# 2           294   20:29.8  25:24.0              3195            Sip Ave
# 3            97   21:13.8  22:51.6              3202       Newport PATH
# 4           286   29:58.0  34:44.2              3195            Sip Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.715178               -74.037683            3198
# 1               40.730897               -74.063913            3679
# 2               40.730897               -74.063913            3678
# 3               40.727224               -74.033759            3638
# 4               40.730897               -74.063913            3679
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0  Heights Elevator             40.748716             -74.040443   29462
# 1        Bergen Ave             40.722104             -74.071455   29610
# 2     Fairmount Ave             40.725726             -74.071959   26166
# 3     Washington St             40.724294             -74.035483   29492
# 4        Bergen Ave             40.722104             -74.071455   29440
#
#      usertype  birth year  gender
# 0  Subscriber        1980       1
# 1  Subscriber        1956       1
# 2  Subscriber        1977       1
# 3  Subscriber        1993       1
# 4    Customer        1990       1

# %%
total_rows=len(df.axes[0])

# %%
print("Number of Rows: " +str(total_rows))
# Out:
# Number of Rows: 68710

# %%
df.to_csv("2020-citibike-all.csv", index=False)

# %%
# Read in new csv
df = pd.read_csv("2020-citibike-all.csv")
df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0          1553   07:13.9  33:07.7              3681           Grand St
# 1           416   16:40.5  23:36.6              3195            Sip Ave
# 2           294   20:29.8  25:24.0              3195            Sip Ave
# 3            97   21:13.8  22:51.6              3202       Newport PATH
# 4           286   29:58.0  34:44.2              3195            Sip Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.715178               -74.037683            3198
# 1               40.730897               -74.063913            3679
# 2               40.730897               -74.063913            3678
# 3               40.727224               -74.033759            3638
# 4               40.730897               -74.063913            3679
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0  Heights Elevator             40.748716             -74.040443   29462
# 1        Bergen Ave             40.722104             -74.071455   29610
# 2     Fairmount Ave             40.725726             -74.071959   26166
# 3     Washington St             40.724294             -74.035483   29492
# 4        Bergen Ave             40.722104             -74.071455   29440
#
#      usertype  birth year  gender
# 0  Subscriber        1980       1
# 1  Subscriber        1956       1
# 2  Subscriber        1977       1
# 3  Subscriber        1993       1
# 4    Customer        1990       1

# %%
# Convert trip duration column from seconds to minutes
df["tripduration"] = [trip/60 for trip in df["tripduration"]]

# Filter out trips over 24 hours long
df = df.loc[df["tripduration"] < 1440, :]

# Rename trip duration column
df.rename(columns={"tripduration":"tripduration (min)"})

df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0     25.883333   07:13.9  33:07.7              3681           Grand St
# 1      6.933333   16:40.5  23:36.6              3195            Sip Ave
# 2      4.900000   20:29.8  25:24.0              3195            Sip Ave
# 3      1.616667   21:13.8  22:51.6              3202       Newport PATH
# 4      4.766667   29:58.0  34:44.2              3195            Sip Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.715178               -74.037683            3198
# 1               40.730897               -74.063913            3679
# 2               40.730897               -74.063913            3678
# 3               40.727224               -74.033759            3638
# 4               40.730897               -74.063913            3679
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0  Heights Elevator             40.748716             -74.040443   29462
# 1        Bergen Ave             40.722104             -74.071455   29610
# 2     Fairmount Ave             40.725726             -74.071959   26166
# 3     Washington St             40.724294             -74.035483   29492
# 4        Bergen Ave             40.722104             -74.071455   29440
#
#      usertype  birth year  gender
# 0  Subscriber        1980       1
# 1  Subscriber        1956       1
# 2  Subscriber        1977       1
# 3  Subscriber        1993       1
# 4    Customer        1990       1

# %%
# Rename values in gender column with strings
gender = {0:"Unknown", 1:"Male", 2:"Female"}
df.gender = [gender[item] for item in df.gender]
df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0     25.883333   07:13.9  33:07.7              3681           Grand St
# 1      6.933333   16:40.5  23:36.6              3195            Sip Ave
# 2      4.900000   20:29.8  25:24.0              3195            Sip Ave
# 3      1.616667   21:13.8  22:51.6              3202       Newport PATH
# 4      4.766667   29:58.0  34:44.2              3195            Sip Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.715178               -74.037683            3198
# 1               40.730897               -74.063913            3679
# 2               40.730897               -74.063913            3678
# 3               40.727224               -74.033759            3638
# 4               40.730897               -74.063913            3679
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0  Heights Elevator             40.748716             -74.040443   29462
# 1        Bergen Ave             40.722104             -74.071455   29610
# 2     Fairmount Ave             40.725726             -74.071959   26166
# 3     Washington St             40.724294             -74.035483   29492
# 4        Bergen Ave             40.722104             -74.071455   29440
#
#      usertype  birth year gender
# 0  Subscriber        1980   Male
# 1  Subscriber        1956   Male
# 2  Subscriber        1977   Male
# 3  Subscriber        1993   Male
# 4    Customer        1990   Male

# %%
# Add ride id column to uniquely identify each ride
df["rideid"] = df["start station id"].map(str) + "_" + df["end station id"].map(str)
df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0     25.883333   07:13.9  33:07.7              3681           Grand St
# 1      6.933333   16:40.5  23:36.6              3195            Sip Ave
# 2      4.900000   20:29.8  25:24.0              3195            Sip Ave
# 3      1.616667   21:13.8  22:51.6              3202       Newport PATH
# 4      4.766667   29:58.0  34:44.2              3195            Sip Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.715178               -74.037683            3198
# 1               40.730897               -74.063913            3679
# 2               40.730897               -74.063913            3678
# 3               40.727224               -74.033759            3638
# 4               40.730897               -74.063913            3679
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0  Heights Elevator             40.748716             -74.040443   29462
# 1        Bergen Ave             40.722104             -74.071455   29610
# 2     Fairmount Ave             40.725726             -74.071959   26166
# 3     Washington St             40.724294             -74.035483   29492
# 4        Bergen Ave             40.722104             -74.071455   29440
#
#      usertype  birth year gender     rideid
# 0  Subscriber        1980   Male  3681_3198
# 1  Subscriber        1956   Male  3195_3679
# 2  Subscriber        1977   Male  3195_3678
# 3  Subscriber        1993   Male  3202_3638
# 4    Customer        1990   Male  3195_3679

# %%
from math import sin, cos, sqrt, atan2, radians

# Convert degrees to radians
lat1 = [radians(lat) for lat in df["start station latitude"]]
lon1 = [radians(lon) for lon in df["start station longitude"]]
lat2 = [radians(lat) for lat in df["end station latitude"]]
lon2 = [radians(lon) for lon in df["end station longitude"]]

# Convert lists into series
lat1 = pd.Series(lat1)
lon1 = pd.Series(lon1)
lat2 = pd.Series(lat2)
lon2 = pd.Series(lon2)

# Calculate difference between each set of latitude and longitude
dlat = lat2 - lat1
dlon = lon2 - lon1

# %%
# Approximate radius of Earth in km
R = 6373.0

# Empty list to store trip distances
distance = []

for i in range(0, len(lat1)):
    
    a = sin(dlat[i] / 2)**2 + cos(lat1[i]) * cos(lat2[i]) * sin(dlon[i] / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    # Get distance and convert km to miles
    miles = (R * c) * .6214
    
    # Append miles travel to 'distance' list
    distance.append(miles)

# %%
# Add trip distance as new column to data frame
df["tripdistance (mi)"] = distance
df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0     25.883333   07:13.9  33:07.7              3681           Grand St
# 1      6.933333   16:40.5  23:36.6              3195            Sip Ave
# 2      4.900000   20:29.8  25:24.0              3195            Sip Ave
# 3      1.616667   21:13.8  22:51.6              3202       Newport PATH
# 4      4.766667   29:58.0  34:44.2              3195            Sip Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.715178               -74.037683            3198
# 1               40.730897               -74.063913            3679
# 2               40.730897               -74.063913            3678
# 3               40.727224               -74.033759            3638
# 4               40.730897               -74.063913            3679
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0  Heights Elevator             40.748716             -74.040443   29462
# 1        Bergen Ave             40.722104             -74.071455   29610
# 2     Fairmount Ave             40.725726             -74.071959   26166
# 3     Washington St             40.724294             -74.035483   29492
# 4        Bergen Ave             40.722104             -74.071455   29440
#
#      usertype  birth year gender     rideid  tripdistance (mi)
# 0  Subscriber        1980   Male  3681_3198           2.322608
# 1  Subscriber        1956   Male  3195_3679           0.724896
# 2  Subscriber        1977   Male  3195_3678           0.552610
# 3  Subscriber        1993   Male  3202_3638           0.221694
# 4    Customer        1990   Male  3195_3679           0.724896

# %%
# Calculate age of riders
ages = []

for i in df["birth year"]:
    age = 2019 - i
    ages.append(age)

# %%
# Append new Age column
df["Age"] = ages
df
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0         25.883333   07:13.9  33:07.7              3681           Grand St
# 1          6.933333   16:40.5  23:36.6              3195            Sip Ave
# 2          4.900000   20:29.8  25:24.0              3195            Sip Ave
# 3          1.616667   21:13.8  22:51.6              3202       Newport PATH
# 4          4.766667   29:58.0  34:44.2              3195            Sip Ave
# ...             ...       ...      ...               ...                ...
# 68705      4.366667   40:53.2  45:15.3              3639         Harborside
# 68706      3.600000   41:01.3  44:38.0              3186      Grove St PATH
# 68707      1.683333   45:22.2  47:03.3              3214   Essex Light Rail
# 68708      4.650000   47:56.8  52:36.6              3186      Grove St PATH
# 68709      3.533333   49:18.5  52:50.7              3184        Paulus Hook
#
#        start station latitude  start station longitude  end station id  \
# 0                   40.715178               -74.037683            3198
# 1                   40.730897               -74.063913            3679
# 2                   40.730897               -74.063913            3678
# 3                   40.727224               -74.033759            3638
# 4                   40.730897               -74.063913            3679
# ...                       ...                      ...             ...
# 68705               40.719252               -74.034234            3214
# 68706               40.719586               -74.043117            3483
# 68707               40.712774               -74.036486            3681
# 68708               40.719586               -74.043117            3483
# 68709               40.714145               -74.033552            3276
#
#        end station name  end station latitude  end station longitude  bikeid  \
# 0      Heights Elevator             40.748716             -74.040443   29462
# 1            Bergen Ave             40.722104             -74.071455   29610
# 2         Fairmount Ave             40.725726             -74.071959   26166
# 3         Washington St             40.724294             -74.035483   29492
# 4            Bergen Ave             40.722104             -74.071455   29440
# ...                 ...                   ...                    ...     ...
# 68705  Essex Light Rail             40.712774             -74.036486   42467
# 68706     Montgomery St             40.719420             -74.050990   42377
# 68707          Grand St             40.715178             -74.037683   42485
# 68708     Montgomery St             40.719420             -74.050990   42531
# 68709  Marin Light Rail             40.714584             -74.042817   42385
#
#          usertype  birth year gender     rideid  tripdistance (mi)  Age
# 0      Subscriber        1980   Male  3681_3198           2.322608   39
# 1      Subscriber        1956   Male  3195_3679           0.724896   63
# 2      Subscriber        1977   Male  3195_3678           0.552610   42
# 3      Subscriber        1993   Male  3202_3638           0.221694   26
# 4        Customer        1990   Male  3195_3679           0.724896   29
# ...           ...         ...    ...        ...                ...  ...
# 68705  Subscriber        1967   Male  3639_3214           0.462993   52
# 68706  Subscriber        1958   Male  3186_3483           0.412567   61
# 68707  Subscriber        1967   Male  3214_3681           0.177578   52
# 68708  Subscriber        1988   Male  3186_3483           0.412567   31
# 68709  Subscriber        1967   Male  3184_3276           0.486344   52
#
# [68686 rows x 18 columns]

# %%
# Delete all rows where user age is over 90
df = df.loc[df["Age"] < 90]

# %%
# Divide users in age bins
bins = [0, 17, 25, 35, 50, 65, 90]
labels = ["0-17", "18-25", "26-35", "36-50", "51-65", "65-90"]

df["Age Group"] = pd.cut(df["Age"], bins, labels=labels)

# %%
# Delete column
del df["birth year"]

# %%
df
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0         25.883333   07:13.9  33:07.7              3681           Grand St
# 1          6.933333   16:40.5  23:36.6              3195            Sip Ave
# 2          4.900000   20:29.8  25:24.0              3195            Sip Ave
# 3          1.616667   21:13.8  22:51.6              3202       Newport PATH
# 4          4.766667   29:58.0  34:44.2              3195            Sip Ave
# ...             ...       ...      ...               ...                ...
# 68705      4.366667   40:53.2  45:15.3              3639         Harborside
# 68706      3.600000   41:01.3  44:38.0              3186      Grove St PATH
# 68707      1.683333   45:22.2  47:03.3              3214   Essex Light Rail
# 68708      4.650000   47:56.8  52:36.6              3186      Grove St PATH
# 68709      3.533333   49:18.5  52:50.7              3184        Paulus Hook
#
#        start station latitude  start station longitude  end station id  \
# 0                   40.715178               -74.037683            3198
# 1                   40.730897               -74.063913            3679
# 2                   40.730897               -74.063913            3678
# 3                   40.727224               -74.033759            3638
# 4                   40.730897               -74.063913            3679
# ...                       ...                      ...             ...
# 68705               40.719252               -74.034234            3214
# 68706               40.719586               -74.043117            3483
# 68707               40.712774               -74.036486            3681
# 68708               40.719586               -74.043117            3483
# 68709               40.714145               -74.033552            3276
#
#        end station name  end station latitude  end station longitude  bikeid  \
# 0      Heights Elevator             40.748716             -74.040443   29462
# 1            Bergen Ave             40.722104             -74.071455   29610
# 2         Fairmount Ave             40.725726             -74.071959   26166
# 3         Washington St             40.724294             -74.035483   29492
# 4            Bergen Ave             40.722104             -74.071455   29440
# ...                 ...                   ...                    ...     ...
# 68705  Essex Light Rail             40.712774             -74.036486   42467
# 68706     Montgomery St             40.719420             -74.050990   42377
# 68707          Grand St             40.715178             -74.037683   42485
# 68708     Montgomery St             40.719420             -74.050990   42531
# 68709  Marin Light Rail             40.714584             -74.042817   42385
#
#          usertype gender     rideid  tripdistance (mi)  Age Age Group
# 0      Subscriber   Male  3681_3198           2.322608   39     36-50
# 1      Subscriber   Male  3195_3679           0.724896   63     51-65
# 2      Subscriber   Male  3195_3678           0.552610   42     36-50
# 3      Subscriber   Male  3202_3638           0.221694   26     26-35
# 4        Customer   Male  3195_3679           0.724896   29     26-35
# ...           ...    ...        ...                ...  ...       ...
# 68705  Subscriber   Male  3639_3214           0.462993   52     51-65
# 68706  Subscriber   Male  3186_3483           0.412567   61     51-65
# 68707  Subscriber   Male  3214_3681           0.177578   52     51-65
# 68708  Subscriber   Male  3186_3483           0.412567   31     26-35
# 68709  Subscriber   Male  3184_3276           0.486344   52     51-65
#
# [68663 rows x 18 columns]

# %%
df.to_csv("2020-citibike-ALL2.csv", index=False)
